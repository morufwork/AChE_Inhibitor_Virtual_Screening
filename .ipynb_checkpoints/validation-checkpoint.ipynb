# %%
import os
import glob
import joblib
import numpy as np
import pandas as pd

from rdkit import Chem
from rdkit.Chem import rdMolDescriptors

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, precision_recall_curve, auc,
    matthews_corrcoef
)

# ------------------------------------------------------------
# Paths
# ------------------------------------------------------------
PUBCHEM_FILE = "dataset/pubchem_clean.csv"
MODEL_DIR = "saved_models/chembl_topo"
OUTPUT_FILE = "pubchem_test/metrics_topo.csv"

# ------------------------------------------------------------
# Load dataset
# ------------------------------------------------------------
df = pd.read_csv(PUBCHEM_FILE)

smiles_col = "standard_smiles"
label_col = "class"

if smiles_col not in df.columns:
    raise ValueError(f"Column '{smiles_col}' not found in {PUBCHEM_FILE}")

if label_col not in df.columns:
    raise ValueError(
        f"Column '{label_col}' not found in {PUBCHEM_FILE}. "
        f"You need true labels to compute the evaluation table."
    )

# ------------------------------------------------------------
# Convert SMILES to molecules
# ------------------------------------------------------------
df["mol"] = df[smiles_col].apply(Chem.MolFromSmiles)
df = df[df["mol"].notnull()].copy().reset_index(drop=True)

print(f"Valid molecules: {len(df)}")

# ------------------------------------------------------------
# Generate the SAME fingerprint used during training
# ------------------------------------------------------------
def mol_to_tt_fp(mol):
    return rdMolDescriptors.GetHashedTopologicalTorsionFingerprintAsBitVect(
        mol, nBits=2048
    )

df["fp"] = df["mol"].apply(mol_to_tt_fp)

# safer conversion from RDKit ExplicitBitVect to numpy array
X = np.array([list(fp) for fp in df["fp"]], dtype=np.uint8)
y = df[label_col].astype(int).to_numpy()

# ------------------------------------------------------------
# Metrics functions
# ------------------------------------------------------------
def enrichment_factor(y_true, y_scores, top_percent=0.01):
    sorted_idx = np.argsort(y_scores)[::-1]
    y_true_sorted = np.array(y_true)[sorted_idx]

    n_total = len(y_true)
    n_actives = np.sum(y_true)

    top_n = int(np.ceil(top_percent * n_total))
    top_hits = y_true_sorted[:top_n]

    n_top_actives = np.sum(top_hits)

    if n_actives == 0 or top_n == 0:
        return 0.0

    ef = (n_top_actives / top_n) / (n_actives / n_total)
    return ef


def bedroc_score(y_true, y_scores, alpha=20.0):
    y_true = np.array(y_true)
    y_scores = np.array(y_scores)

    order = np.argsort(y_scores)[::-1]
    y_true = y_true[order]

    n = len(y_true)
    n_pos = np.sum(y_true)

    if n_pos == 0:
        return 0.0

    ranks = np.where(y_true == 1)[0] + 1   # 1-based ranks
    ri = ranks / n

    rie = np.sum(np.exp(-alpha * ri)) / n_pos

    rand = (1 - np.exp(-alpha)) / alpha
    max_rie = (1 - np.exp(-alpha * (n_pos / n))) / (alpha * (n_pos / n))

    if max_rie == rand:
        return 0.0

    bedroc = (rie - rand) / (max_rie - rand)
    return bedroc

# ------------------------------------------------------------
# Load all saved models
# ------------------------------------------------------------
model_files = sorted(glob.glob(os.path.join(MODEL_DIR, "*.joblib")))

if not model_files:
    raise FileNotFoundError(f"No saved model found in {MODEL_DIR}")

# nice model names from filenames
def clean_model_name(path):
    name = os.path.splitext(os.path.basename(path))[0]
    return name.replace("_", " ").title()

# ------------------------------------------------------------
# Evaluate all models on PubChem
# ------------------------------------------------------------
results = []

for model_path in model_files:
    model_name = clean_model_name(model_path)
    print(f"\nEvaluating {model_name} ...")

    model = joblib.load(model_path)

    y_pred = model.predict(X)

    if hasattr(model, "predict_proba"):
        y_prob = model.predict_proba(X)[:, 1]
    else:
        y_prob = None

    acc = accuracy_score(y, y_pred)
    prec = precision_score(y, y_pred, zero_division=0)
    rec = recall_score(y, y_pred, zero_division=0)
    f1 = f1_score(y, y_pred, zero_division=0)
    mcc = matthews_corrcoef(y, y_pred)

    if y_prob is not None:
        roc = roc_auc_score(y, y_prob)

        p, r, _ = precision_recall_curve(y, y_prob)
        pra = auc(r, p)

        ef1 = enrichment_factor(y, y_prob, top_percent=0.01)
        ef5 = enrichment_factor(y, y_prob, top_percent=0.05)
        ef10 = enrichment_factor(y, y_prob, top_percent=0.10)

        bedroc = bedroc_score(y, y_prob, alpha=20)
    else:
        roc = np.nan
        pra = np.nan
        ef1 = np.nan
        ef5 = np.nan
        ef10 = np.nan
        bedroc = np.nan

    results.append([
        model_name, acc, prec, rec, f1, roc, pra, ef1, ef5, ef10, bedroc, mcc
    ])

# ------------------------------------------------------------
# Results table
# ------------------------------------------------------------
columns = [
    "Model",
    "Accuracy",
    "Precision",
    "Recall",
    "F1",
    "ROC_AUC",
    "PR_AUC",
    "EF@1%",
    "EF@5%",
    "EF@10%",
    "BEDROC",
    "MCC"
]

results_df = pd.DataFrame(results, columns=columns)
results_df = results_df.sort_values("PR_AUC", ascending=False)

print("\n==================== PUBCHEM TEST RESULTS ====================")
print(results_df)

results_df.to_csv(OUTPUT_FILE, index=False)
print(f"\nSaved results to: {OUTPUT_FILE}")
# Out:
# Valid molecules: 689
#
# Evaluating Adaboost ...
#
# Evaluating Decision Tree ...
#
# Evaluating Extra Trees ...
#
# Evaluating Gradient Boosting ...
#
# Evaluating Knn ...
#
# Evaluating Lightgbm ...
#
# Evaluating Logistic Regression ...
#
# Evaluating Naive Bayes ...
#
# Evaluating Random Forest ...
#
# Evaluating Svm ...
#
# ==================== PUBCHEM TEST RESULTS ====================
#                  Model  Accuracy  Precision    Recall        F1   ROC_AUC  \
# 3    Gradient Boosting  0.830189   0.696246  0.879310  0.777143  0.915081
# 9                  Svm  0.818578   0.681356  0.866379  0.762808  0.904267
# 8        Random Forest  0.820029   0.680000  0.879310  0.766917  0.896542
# 2          Extra Trees  0.789550   0.639871  0.857759  0.732965  0.884710
# 4                  Knn  0.786647   0.640264  0.836207  0.725234  0.866162
# 5             Lightgbm  0.747460   0.586310  0.849138  0.693662  0.859843
# 0             Adaboost  0.772134   0.610619  0.892241  0.725044  0.863903
# 7          Naive Bayes  0.519594   0.405714  0.918103  0.562748  0.617346
# 1        Decision Tree  0.648766   0.485465  0.719828  0.579861  0.665599
# 6  Logistic Regression  0.679245   0.514512  0.840517  0.638298  0.786001
#
#      PR_AUC     EF@1%     EF@5%    EF@10%    BEDROC       MCC
# 3  0.854364  2.969828  2.969828  2.840705  0.912593  0.654385
# 9  0.843348  2.969828  2.969828  2.797664  0.900466  0.631017
# 8  0.834721  2.969828  2.969828  2.969828  0.910916  0.637899
# 2  0.823964  2.969828  2.969828  2.926787  0.905454  0.581850
# 4  0.807943  2.969828  2.884975  2.582459  0.830358  0.569071
# 5  0.781820  2.969828  2.969828  2.840705  0.875799  0.515259
# 0  0.738682  2.121305  2.715271  2.539418  0.755164  0.570393
# 7  0.675528  0.424261  0.763670  0.903861 -0.126774  0.261209
# 1  0.646845  0.000000  0.848522  0.903861 -0.057706  0.314289
# 6  0.605897  0.848522  2.121305  2.238131  0.519038  0.415976
#
# Saved results to: pubchem_test/metrics_topo.csv

# %%
import os
import glob
import joblib
import numpy as np
import pandas as pd

from rdkit import Chem
from rdkit.Chem import RDKFingerprint

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, precision_recall_curve, auc,
    matthews_corrcoef
)

# ------------------------------------------------------------
# Paths
# ------------------------------------------------------------
PUBCHEM_FILE = "dataset/pubchem_clean.csv"
MODEL_DIR = "saved_models/chembl_rdk"
OUTPUT_FILE = "pubchem_test/metrics_rdk.csv"

# ------------------------------------------------------------
# Load dataset
# ------------------------------------------------------------
df = pd.read_csv(PUBCHEM_FILE)

smiles_col = "standard_smiles"
label_col = "class"

if smiles_col not in df.columns:
    raise ValueError(f"Column '{smiles_col}' not found in {PUBCHEM_FILE}")

if label_col not in df.columns:
    raise ValueError(
        f"Column '{label_col}' not found in {PUBCHEM_FILE}. "
        f"You need true labels to compute the evaluation table."
    )

# ------------------------------------------------------------
# Convert SMILES to molecules
# ------------------------------------------------------------
df["mol"] = df[smiles_col].apply(Chem.MolFromSmiles)
df = df[df["mol"].notnull()].copy().reset_index(drop=True)

print(f"Valid molecules: {len(df)}")

# ------------------------------------------------------------
# Generate the SAME fingerprint used during training
# ------------------------------------------------------------
# Generate RDKit Topological Fingerprints (default: 2048 bits)
def mol_to_rdkit_fp(mol):
    return RDKFingerprint(mol)

df['fp'] = df['mol'].apply(mol_to_rdkit_fp)

# ✅ Convert fingerprints to NumPy arrays
X = np.array([np.array(fp) for fp in df['fp']])
y = df['class'].astype(int)

# ------------------------------------------------------------
# Metrics functions
# ------------------------------------------------------------
def enrichment_factor(y_true, y_scores, top_percent=0.01):
    sorted_idx = np.argsort(y_scores)[::-1]
    y_true_sorted = np.array(y_true)[sorted_idx]

    n_total = len(y_true)
    n_actives = np.sum(y_true)

    top_n = int(np.ceil(top_percent * n_total))
    top_hits = y_true_sorted[:top_n]

    n_top_actives = np.sum(top_hits)

    if n_actives == 0 or top_n == 0:
        return 0.0

    ef = (n_top_actives / top_n) / (n_actives / n_total)
    return ef


def bedroc_score(y_true, y_scores, alpha=20.0):
    y_true = np.array(y_true)
    y_scores = np.array(y_scores)

    order = np.argsort(y_scores)[::-1]
    y_true = y_true[order]

    n = len(y_true)
    n_pos = np.sum(y_true)

    if n_pos == 0:
        return 0.0

    ranks = np.where(y_true == 1)[0] + 1   # 1-based ranks
    ri = ranks / n

    rie = np.sum(np.exp(-alpha * ri)) / n_pos

    rand = (1 - np.exp(-alpha)) / alpha
    max_rie = (1 - np.exp(-alpha * (n_pos / n))) / (alpha * (n_pos / n))

    if max_rie == rand:
        return 0.0

    bedroc = (rie - rand) / (max_rie - rand)
    return bedroc

# ------------------------------------------------------------
# Load all saved models
# ------------------------------------------------------------
model_files = sorted(glob.glob(os.path.join(MODEL_DIR, "*.joblib")))

if not model_files:
    raise FileNotFoundError(f"No saved model found in {MODEL_DIR}")

# nice model names from filenames
def clean_model_name(path):
    name = os.path.splitext(os.path.basename(path))[0]
    return name.replace("_", " ").title()

# ------------------------------------------------------------
# Evaluate all models on PubChem
# ------------------------------------------------------------
results = []

for model_path in model_files:
    model_name = clean_model_name(model_path)
    print(f"\nEvaluating {model_name} ...")

    model = joblib.load(model_path)

    y_pred = model.predict(X)

    if hasattr(model, "predict_proba"):
        y_prob = model.predict_proba(X)[:, 1]
    else:
        y_prob = None

    acc = accuracy_score(y, y_pred)
    prec = precision_score(y, y_pred, zero_division=0)
    rec = recall_score(y, y_pred, zero_division=0)
    f1 = f1_score(y, y_pred, zero_division=0)
    mcc = matthews_corrcoef(y, y_pred)

    if y_prob is not None:
        roc = roc_auc_score(y, y_prob)

        p, r, _ = precision_recall_curve(y, y_prob)
        pra = auc(r, p)

        ef1 = enrichment_factor(y, y_prob, top_percent=0.01)
        ef5 = enrichment_factor(y, y_prob, top_percent=0.05)
        ef10 = enrichment_factor(y, y_prob, top_percent=0.10)

        bedroc = bedroc_score(y, y_prob, alpha=20)
    else:
        roc = np.nan
        pra = np.nan
        ef1 = np.nan
        ef5 = np.nan
        ef10 = np.nan
        bedroc = np.nan

    results.append([
        model_name, acc, prec, rec, f1, roc, pra, ef1, ef5, ef10, bedroc, mcc
    ])

# ------------------------------------------------------------
# Results table
# ------------------------------------------------------------
columns = [
    "Model",
    "Accuracy",
    "Precision",
    "Recall",
    "F1",
    "ROC_AUC",
    "PR_AUC",
    "EF@1%",
    "EF@5%",
    "EF@10%",
    "BEDROC",
    "MCC"
]

results_df = pd.DataFrame(results, columns=columns)
results_df = results_df.sort_values("PR_AUC", ascending=False)

print("\n==================== PUBCHEM TEST RESULTS ====================")
print(results_df)

results_df.to_csv(OUTPUT_FILE, index=False)
print(f"\nSaved results to: {OUTPUT_FILE}")
# Out:
# Valid molecules: 689
#
# Evaluating Adaboost ...
#
# Evaluating Decision Tree ...
#
# Evaluating Extra Trees ...
#
# Evaluating Gradient Boosting ...
#
# Evaluating Knn ...
#
# Evaluating Lightgbm ...
#
# Evaluating Logistic Regression ...
#
# Evaluating Naive Bayes ...
#
# Evaluating Random Forest ...
#
# Evaluating Svm ...
#
# ==================== PUBCHEM TEST RESULTS ====================
#                  Model  Accuracy  Precision    Recall        F1   ROC_AUC  \
# 8        Random Forest  0.786647   0.641196  0.831897  0.724203  0.881018
# 5             Lightgbm  0.777939   0.630363  0.823276  0.714019  0.877825
# 2          Extra Trees  0.772134   0.618297  0.844828  0.714026  0.876113
# 3    Gradient Boosting  0.773585   0.623377  0.827586  0.711111  0.882380
# 9                  Svm  0.828737   0.717557  0.810345  0.761134  0.877622
# 4                  Knn  0.714078   0.548747  0.849138  0.666667  0.840729
# 0             Adaboost  0.756168   0.601266  0.818966  0.693431  0.849275
# 7          Naive Bayes  0.735849   0.593284  0.685345  0.636000  0.807034
# 6  Logistic Regression  0.689405   0.526163  0.780172  0.628472  0.793254
# 1        Decision Tree  0.605225   0.448187  0.745690  0.559871  0.639803
#
#      PR_AUC     EF@1%     EF@5%    EF@10%    BEDROC       MCC
# 8  0.856523  2.969828  2.969828  2.969828  0.950214  0.567463
# 5  0.846296  2.969828  2.969828  2.969828  0.949238  0.550509
# 2  0.839909  2.969828  2.969828  2.840705  0.922780  0.550012
# 3  0.827994  2.969828  2.969828  2.926787  0.923870  0.545371
# 9  0.823929  2.969828  2.969828  2.926787  0.909753  0.631238
# 4  0.776404  2.545567  2.545567  2.367254  0.682334  0.467948
# 0  0.769749  2.969828  2.969828  2.754623  0.863833  0.515237
# 7  0.712283  2.545567  1.951601  1.678598  0.445666  0.433150
# 6  0.665870  2.969828  2.630419  2.367254  0.697986  0.400281
# 1  0.639754  1.272783  2.121305  1.764680  0.362612  0.266216
#
# Saved results to: pubchem_test/metrics_rdk.csv

# %%
import os
import glob
import joblib
import numpy as np
import pandas as pd

from rdkit import Chem
from rdkit.Chem import rdMolDescriptors

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, precision_recall_curve, auc,
    matthews_corrcoef
)

# ------------------------------------------------------------
# Paths
# ------------------------------------------------------------
PUBCHEM_FILE = "dataset/pubchem_clean.csv"
MODEL_DIR = "saved_models/chembl_morgan"
OUTPUT_FILE = "pubchem_test/metrics_morgan.csv"

# ------------------------------------------------------------
# Load dataset
# ------------------------------------------------------------
df = pd.read_csv(PUBCHEM_FILE)

smiles_col = "standard_smiles"
label_col = "class"

if smiles_col not in df.columns:
    raise ValueError(f"Column '{smiles_col}' not found in {PUBCHEM_FILE}")

if label_col not in df.columns:
    raise ValueError(
        f"Column '{label_col}' not found in {PUBCHEM_FILE}. "
        f"You need true labels to compute the evaluation table."
    )

# ------------------------------------------------------------
# Convert SMILES to molecules
# ------------------------------------------------------------
df["mol"] = df[smiles_col].apply(Chem.MolFromSmiles)
df = df[df["mol"].notnull()].copy().reset_index(drop=True)

print(f"Valid molecules: {len(df)}")

# ------------------------------------------------------------
# Generate the SAME fingerprint used during training
# ------------------------------------------------------------
# ✅ Generate Morgan Keys
def mol_to_morgan_counts(mol, radius=2, nBits=2048):
    fp = rdMolDescriptors.GetHashedMorganFingerprint(
        mol,
        radius=radius,
        nBits=nBits
    )
    # Convert to dense NumPy array
    arr = np.zeros((nBits,), dtype=int)
    for idx, value in fp.GetNonzeroElements().items():
        arr[idx] = value
    return arr

df['fp'] = df['mol'].apply(mol_to_morgan_counts)

# Convert fingerprints to NumPy matrix
X = np.vstack(df['fp'].values)
y = df['class'].astype(int)


# ------------------------------------------------------------
# Metrics functions
# ------------------------------------------------------------
def enrichment_factor(y_true, y_scores, top_percent=0.01):
    sorted_idx = np.argsort(y_scores)[::-1]
    y_true_sorted = np.array(y_true)[sorted_idx]

    n_total = len(y_true)
    n_actives = np.sum(y_true)

    top_n = int(np.ceil(top_percent * n_total))
    top_hits = y_true_sorted[:top_n]

    n_top_actives = np.sum(top_hits)

    if n_actives == 0 or top_n == 0:
        return 0.0

    ef = (n_top_actives / top_n) / (n_actives / n_total)
    return ef


def bedroc_score(y_true, y_scores, alpha=20.0):
    y_true = np.array(y_true)
    y_scores = np.array(y_scores)

    order = np.argsort(y_scores)[::-1]
    y_true = y_true[order]

    n = len(y_true)
    n_pos = np.sum(y_true)

    if n_pos == 0:
        return 0.0

    ranks = np.where(y_true == 1)[0] + 1   # 1-based ranks
    ri = ranks / n

    rie = np.sum(np.exp(-alpha * ri)) / n_pos

    rand = (1 - np.exp(-alpha)) / alpha
    max_rie = (1 - np.exp(-alpha * (n_pos / n))) / (alpha * (n_pos / n))

    if max_rie == rand:
        return 0.0

    bedroc = (rie - rand) / (max_rie - rand)
    return bedroc

# ------------------------------------------------------------
# Load all saved models
# ------------------------------------------------------------
model_files = sorted(glob.glob(os.path.join(MODEL_DIR, "*.joblib")))

if not model_files:
    raise FileNotFoundError(f"No saved model found in {MODEL_DIR}")

# nice model names from filenames
def clean_model_name(path):
    name = os.path.splitext(os.path.basename(path))[0]
    return name.replace("_", " ").title()

# ------------------------------------------------------------
# Evaluate all models on PubChem
# ------------------------------------------------------------
results = []

for model_path in model_files:
    model_name = clean_model_name(model_path)
    print(f"\nEvaluating {model_name} ...")

    model = joblib.load(model_path)

    y_pred = model.predict(X)

    if hasattr(model, "predict_proba"):
        y_prob = model.predict_proba(X)[:, 1]
    else:
        y_prob = None

    acc = accuracy_score(y, y_pred)
    prec = precision_score(y, y_pred, zero_division=0)
    rec = recall_score(y, y_pred, zero_division=0)
    f1 = f1_score(y, y_pred, zero_division=0)
    mcc = matthews_corrcoef(y, y_pred)

    if y_prob is not None:
        roc = roc_auc_score(y, y_prob)

        p, r, _ = precision_recall_curve(y, y_prob)
        pra = auc(r, p)

        ef1 = enrichment_factor(y, y_prob, top_percent=0.01)
        ef5 = enrichment_factor(y, y_prob, top_percent=0.05)
        ef10 = enrichment_factor(y, y_prob, top_percent=0.10)

        bedroc = bedroc_score(y, y_prob, alpha=20)
    else:
        roc = np.nan
        pra = np.nan
        ef1 = np.nan
        ef5 = np.nan
        ef10 = np.nan
        bedroc = np.nan

    results.append([
        model_name, acc, prec, rec, f1, roc, pra, ef1, ef5, ef10, bedroc, mcc
    ])

# ------------------------------------------------------------
# Results table
# ------------------------------------------------------------
columns = [
    "Model",
    "Accuracy",
    "Precision",
    "Recall",
    "F1",
    "ROC_AUC",
    "PR_AUC",
    "EF@1%",
    "EF@5%",
    "EF@10%",
    "BEDROC",
    "MCC"
]

results_df = pd.DataFrame(results, columns=columns)
results_df = results_df.sort_values("PR_AUC", ascending=False)

print("\n==================== PUBCHEM TEST RESULTS ====================")
print(results_df)

results_df.to_csv(OUTPUT_FILE, index=False)
print(f"\nSaved results to: {OUTPUT_FILE}")
# Out:
# Valid molecules: 689
#
# Evaluating Adaboost ...
#
# Evaluating Decision Tree ...
#
# Evaluating Extra Trees ...
#
# Evaluating Gradient Boosting ...
#
# Evaluating Knn ...
#
# Evaluating Lightgbm ...
#
# Evaluating Logistic Regression ...
#
# Evaluating Naive Bayes ...
#
# Evaluating Random Forest ...
#
# Evaluating Svm ...
#
# ==================== PUBCHEM TEST RESULTS ====================
#                  Model  Accuracy  Precision    Recall        F1   ROC_AUC  \
# 8        Random Forest  0.791001   0.641935  0.857759  0.734317  0.898514
# 2          Extra Trees  0.764877   0.611465  0.827586  0.703297  0.886408
# 9                  Svm  0.802612   0.656863  0.866379  0.747212  0.895679
# 3    Gradient Boosting  0.756168   0.593023  0.879310  0.708333  0.881909
# 5             Lightgbm  0.766328   0.611285  0.840517  0.707804  0.874076
# 6  Logistic Regression  0.670537   0.506562  0.831897  0.629690  0.832047
# 4                  Knn  0.711176   0.547009  0.827586  0.658662  0.806445
# 1        Decision Tree  0.616836   0.462085  0.840517  0.596330  0.672819
# 7          Naive Bayes  0.625544   0.467822  0.814655  0.594340  0.669273
# 0             Adaboost  0.738752   0.581761  0.797414  0.672727  0.802149
#
#      PR_AUC     EF@1%     EF@5%    EF@10%    BEDROC       MCC
# 8  0.863236  2.969828  2.969828  2.926787  0.939233  0.584097
# 2  0.848920  2.969828  2.969828  2.926787  0.929775  0.531981
# 9  0.848133  2.969828  2.884975  2.797664  0.896982  0.605511
# 3  0.838667  2.969828  2.969828  2.883746  0.921947  0.541553
# 5  0.816204  2.969828  2.969828  2.840705  0.904212  0.539458
# 6  0.767956  2.969828  2.884975  2.754623  0.870337  0.399714
# 4  0.722836  2.121305  2.121305  1.764680  0.515035  0.453449
# 1  0.678613  1.697044  1.272783  1.377311  0.208802  0.333500
# 7  0.668898  0.424261  1.187931  1.334270  0.058845  0.330289
# 0  0.659064  2.969828  1.442488  2.195090  0.534903  0.480046
#
# Saved results to: pubchem_test/metrics_morgan.csv

# %%
import os
import glob
import joblib
import numpy as np
import pandas as pd

from rdkit import Chem
from rdkit.Chem import MACCSkeys

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, precision_recall_curve, auc,
    matthews_corrcoef
)

# ------------------------------------------------------------
# Paths
# ------------------------------------------------------------
PUBCHEM_FILE = "dataset/pubchem_clean.csv"
MODEL_DIR = "saved_models/chembl_macc"
OUTPUT_FILE = "pubchem_test/metrics_macc.csv"

# ------------------------------------------------------------
# Load dataset
# ------------------------------------------------------------
df = pd.read_csv(PUBCHEM_FILE)

smiles_col = "standard_smiles"
label_col = "class"

if smiles_col not in df.columns:
    raise ValueError(f"Column '{smiles_col}' not found in {PUBCHEM_FILE}")

if label_col not in df.columns:
    raise ValueError(
        f"Column '{label_col}' not found in {PUBCHEM_FILE}. "
        f"You need true labels to compute the evaluation table."
    )

# ------------------------------------------------------------
# Convert SMILES to molecules
# ------------------------------------------------------------
df["mol"] = df[smiles_col].apply(Chem.MolFromSmiles)
df = df[df["mol"].notnull()].copy().reset_index(drop=True)

print(f"Valid molecules: {len(df)}")

# ------------------------------------------------------------
# Generate the SAME fingerprint used during training
# ------------------------------------------------------------
# ✅ Generate MACCS Keys
def mol_to_maccs(mol):
    return MACCSkeys.GenMACCSKeys(mol)  # 167 bits


df["fp"] = df["mol"].apply(mol_to_maccs)

X = np.array([np.array(fp) for fp in df["fp"]])
y = df['class'].astype(int)


# ------------------------------------------------------------
# Metrics functions
# ------------------------------------------------------------
def enrichment_factor(y_true, y_scores, top_percent=0.01):
    sorted_idx = np.argsort(y_scores)[::-1]
    y_true_sorted = np.array(y_true)[sorted_idx]

    n_total = len(y_true)
    n_actives = np.sum(y_true)

    top_n = int(np.ceil(top_percent * n_total))
    top_hits = y_true_sorted[:top_n]

    n_top_actives = np.sum(top_hits)

    if n_actives == 0 or top_n == 0:
        return 0.0

    ef = (n_top_actives / top_n) / (n_actives / n_total)
    return ef


def bedroc_score(y_true, y_scores, alpha=20.0):
    y_true = np.array(y_true)
    y_scores = np.array(y_scores)

    order = np.argsort(y_scores)[::-1]
    y_true = y_true[order]

    n = len(y_true)
    n_pos = np.sum(y_true)

    if n_pos == 0:
        return 0.0

    ranks = np.where(y_true == 1)[0] + 1   # 1-based ranks
    ri = ranks / n

    rie = np.sum(np.exp(-alpha * ri)) / n_pos

    rand = (1 - np.exp(-alpha)) / alpha
    max_rie = (1 - np.exp(-alpha * (n_pos / n))) / (alpha * (n_pos / n))

    if max_rie == rand:
        return 0.0

    bedroc = (rie - rand) / (max_rie - rand)
    return bedroc

# ------------------------------------------------------------
# Load all saved models
# ------------------------------------------------------------
model_files = sorted(glob.glob(os.path.join(MODEL_DIR, "*.joblib")))

if not model_files:
    raise FileNotFoundError(f"No saved model found in {MODEL_DIR}")

# nice model names from filenames
def clean_model_name(path):
    name = os.path.splitext(os.path.basename(path))[0]
    return name.replace("_", " ").title()

# ------------------------------------------------------------
# Evaluate all models on PubChem
# ------------------------------------------------------------
results = []

for model_path in model_files:
    model_name = clean_model_name(model_path)
    print(f"\nEvaluating {model_name} ...")

    model = joblib.load(model_path)

    y_pred = model.predict(X)

    if hasattr(model, "predict_proba"):
        y_prob = model.predict_proba(X)[:, 1]
    else:
        y_prob = None

    acc = accuracy_score(y, y_pred)
    prec = precision_score(y, y_pred, zero_division=0)
    rec = recall_score(y, y_pred, zero_division=0)
    f1 = f1_score(y, y_pred, zero_division=0)
    mcc = matthews_corrcoef(y, y_pred)

    if y_prob is not None:
        roc = roc_auc_score(y, y_prob)

        p, r, _ = precision_recall_curve(y, y_prob)
        pra = auc(r, p)

        ef1 = enrichment_factor(y, y_prob, top_percent=0.01)
        ef5 = enrichment_factor(y, y_prob, top_percent=0.05)
        ef10 = enrichment_factor(y, y_prob, top_percent=0.10)

        bedroc = bedroc_score(y, y_prob, alpha=20)
    else:
        roc = np.nan
        pra = np.nan
        ef1 = np.nan
        ef5 = np.nan
        ef10 = np.nan
        bedroc = np.nan

    results.append([
        model_name, acc, prec, rec, f1, roc, pra, ef1, ef5, ef10, bedroc, mcc
    ])

# ------------------------------------------------------------
# Results table
# ------------------------------------------------------------
columns = [
    "Model",
    "Accuracy",
    "Precision",
    "Recall",
    "F1",
    "ROC_AUC",
    "PR_AUC",
    "EF@1%",
    "EF@5%",
    "EF@10%",
    "BEDROC",
    "MCC"
]

results_df = pd.DataFrame(results, columns=columns)
results_df = results_df.sort_values("PR_AUC", ascending=False)

print("\n==================== PUBCHEM TEST RESULTS ====================")
print(results_df)

results_df.to_csv(OUTPUT_FILE, index=False)
print(f"\nSaved results to: {OUTPUT_FILE}")
# Out:
# Valid molecules: 689
#
# Evaluating Adaboost ...
#
# Evaluating Decision Tree ...
#
# Evaluating Extra Trees ...
#
# Evaluating Gradient Boosting ...
#
# Evaluating Knn ...
#
# Evaluating Lightgbm ...
#
# Evaluating Logistic Regression ...
#
# Evaluating Naive Bayes ...
#
# Evaluating Random Forest ...
#
# Evaluating Svm ...
#
# ==================== PUBCHEM TEST RESULTS ====================
#                  Model  Accuracy  Precision    Recall        F1   ROC_AUC  \
# 8        Random Forest  0.753266   0.592814  0.853448  0.699647  0.886214
# 2          Extra Trees  0.759071   0.600000  0.853448  0.704626  0.887926
# 5             Lightgbm  0.766328   0.617940  0.801724  0.697936  0.853778
# 4                  Knn  0.663280   0.500000  0.883621  0.638629  0.829454
# 3    Gradient Boosting  0.730044   0.567647  0.831897  0.674825  0.840352
# 9                  Svm  0.756168   0.603896  0.801724  0.688889  0.831783
# 1        Decision Tree  0.622642   0.465854  0.823276  0.595016  0.676531
# 6  Logistic Regression  0.671988   0.508523  0.771552  0.613014  0.762610
# 0             Adaboost  0.661829   0.498753  0.862069  0.631912  0.729009
# 7          Naive Bayes  0.555878   0.013158  0.004310  0.006494  0.628452
#
#      PR_AUC     EF@1%     EF@5%    EF@10%    BEDROC       MCC
# 8  0.857875  2.969828  2.969828  2.926787  0.945607  0.525625
# 2  0.839745  2.121305  2.800123  2.840705  0.865138  0.534127
# 5  0.809301  2.969828  2.969828  2.926787  0.921730  0.524121
# 4  0.771850  2.545567  2.375862  2.453336  0.683684  0.418832
# 3  0.770381  2.969828  2.969828  2.754623  0.873140  0.482302
# 9  0.735179  2.969828  2.800123  2.668541  0.792414  0.508309
# 1  0.676139  0.424261  1.527340  1.377311  0.149257  0.331243
# 6  0.548823  0.848522  1.527340  1.764680  0.283546  0.371539
# 0  0.474137  0.424261  0.254557  1.032984 -0.089069  0.404573
# 7  0.382596  0.000000  0.084852  0.043041 -0.357562 -0.241074
#
# Saved results to: pubchem_test/metrics_macc.csv

# %%
import os
import glob
import joblib
import numpy as np
import pandas as pd

from rdkit import Chem
from rdkit.Chem import rdMolDescriptors

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, precision_recall_curve, auc,
    matthews_corrcoef
)

# ------------------------------------------------------------
# Paths
# ------------------------------------------------------------
PUBCHEM_FILE = "dataset/pubchem_clean.csv"
MODEL_DIR = "saved_models/chembl_atompair"
OUTPUT_FILE = "pubchem_test/metrics_atompair.csv"

# ------------------------------------------------------------
# Load dataset
# ------------------------------------------------------------
df = pd.read_csv(PUBCHEM_FILE)

smiles_col = "standard_smiles"
label_col = "class"

if smiles_col not in df.columns:
    raise ValueError(f"Column '{smiles_col}' not found in {PUBCHEM_FILE}")

if label_col not in df.columns:
    raise ValueError(
        f"Column '{label_col}' not found in {PUBCHEM_FILE}. "
        f"You need true labels to compute the evaluation table."
    )

# ------------------------------------------------------------
# Convert SMILES to molecules
# ------------------------------------------------------------
df["mol"] = df[smiles_col].apply(Chem.MolFromSmiles)
df = df[df["mol"].notnull()].copy().reset_index(drop=True)

print(f"Valid molecules: {len(df)}")

# ------------------------------------------------------------
# Generate the SAME fingerprint used during training
# ------------------------------------------------------------
def mol_to_atompair_fp(mol):
    return rdMolDescriptors.GetHashedAtomPairFingerprintAsBitVect(
        mol, nBits=2048
    )


df["fp"] = df["mol"].apply(mol_to_atompair_fp)

X = np.array([np.array(fp) for fp in df["fp"]])
y = df["class"].astype(int).values



# ------------------------------------------------------------
# Metrics functions
# ------------------------------------------------------------
def enrichment_factor(y_true, y_scores, top_percent=0.01):
    sorted_idx = np.argsort(y_scores)[::-1]
    y_true_sorted = np.array(y_true)[sorted_idx]

    n_total = len(y_true)
    n_actives = np.sum(y_true)

    top_n = int(np.ceil(top_percent * n_total))
    top_hits = y_true_sorted[:top_n]

    n_top_actives = np.sum(top_hits)

    if n_actives == 0 or top_n == 0:
        return 0.0

    ef = (n_top_actives / top_n) / (n_actives / n_total)
    return ef


def bedroc_score(y_true, y_scores, alpha=20.0):
    y_true = np.array(y_true)
    y_scores = np.array(y_scores)

    order = np.argsort(y_scores)[::-1]
    y_true = y_true[order]

    n = len(y_true)
    n_pos = np.sum(y_true)

    if n_pos == 0:
        return 0.0

    ranks = np.where(y_true == 1)[0] + 1   # 1-based ranks
    ri = ranks / n

    rie = np.sum(np.exp(-alpha * ri)) / n_pos

    rand = (1 - np.exp(-alpha)) / alpha
    max_rie = (1 - np.exp(-alpha * (n_pos / n))) / (alpha * (n_pos / n))

    if max_rie == rand:
        return 0.0

    bedroc = (rie - rand) / (max_rie - rand)
    return bedroc

# ------------------------------------------------------------
# Load all saved models
# ------------------------------------------------------------
model_files = sorted(glob.glob(os.path.join(MODEL_DIR, "*.joblib")))

if not model_files:
    raise FileNotFoundError(f"No saved model found in {MODEL_DIR}")

# nice model names from filenames
def clean_model_name(path):
    name = os.path.splitext(os.path.basename(path))[0]
    return name.replace("_", " ").title()

# ------------------------------------------------------------
# Evaluate all models on PubChem
# ------------------------------------------------------------
results = []

for model_path in model_files:
    model_name = clean_model_name(model_path)
    print(f"\nEvaluating {model_name} ...")

    model = joblib.load(model_path)

    y_pred = model.predict(X)

    if hasattr(model, "predict_proba"):
        y_prob = model.predict_proba(X)[:, 1]
    else:
        y_prob = None

    acc = accuracy_score(y, y_pred)
    prec = precision_score(y, y_pred, zero_division=0)
    rec = recall_score(y, y_pred, zero_division=0)
    f1 = f1_score(y, y_pred, zero_division=0)
    mcc = matthews_corrcoef(y, y_pred)

    if y_prob is not None:
        roc = roc_auc_score(y, y_prob)

        p, r, _ = precision_recall_curve(y, y_prob)
        pra = auc(r, p)

        ef1 = enrichment_factor(y, y_prob, top_percent=0.01)
        ef5 = enrichment_factor(y, y_prob, top_percent=0.05)
        ef10 = enrichment_factor(y, y_prob, top_percent=0.10)

        bedroc = bedroc_score(y, y_prob, alpha=20)
    else:
        roc = np.nan
        pra = np.nan
        ef1 = np.nan
        ef5 = np.nan
        ef10 = np.nan
        bedroc = np.nan

    results.append([
        model_name, acc, prec, rec, f1, roc, pra, ef1, ef5, ef10, bedroc, mcc
    ])

# ------------------------------------------------------------
# Results table
# ------------------------------------------------------------
columns = [
    "Model",
    "Accuracy",
    "Precision",
    "Recall",
    "F1",
    "ROC_AUC",
    "PR_AUC",
    "EF@1%",
    "EF@5%",
    "EF@10%",
    "BEDROC",
    "MCC"
]

results_df = pd.DataFrame(results, columns=columns)
results_df = results_df.sort_values("PR_AUC", ascending=False)

print("\n==================== PUBCHEM TEST RESULTS ====================")
print(results_df)

results_df.to_csv(OUTPUT_FILE, index=False)
print(f"\nSaved results to: {OUTPUT_FILE}")
# Out:
# Valid molecules: 689
#
# Evaluating Adaboost ...
#
# Evaluating Decision Tree ...
#
# Evaluating Extra Trees ...
#
# Evaluating Gradient Boosting ...
#
# Evaluating Knn ...
#
# Evaluating Lightgbm ...
#
# Evaluating Logistic Regression ...
#
# Evaluating Naive Bayes ...
#
# Evaluating Random Forest ...
#
# Evaluating Svm ...
#
# ==================== PUBCHEM TEST RESULTS ====================
#                  Model  Accuracy  Precision    Recall        F1   ROC_AUC  \
# 9                  Svm  0.812772   0.675768  0.853448  0.754286  0.887686
# 2          Extra Trees  0.746009   0.582133  0.870690  0.697755  0.875387
# 5             Lightgbm  0.783745   0.633441  0.849138  0.725599  0.871774
# 8        Random Forest  0.722787   0.556164  0.875000  0.680067  0.862904
# 3    Gradient Boosting  0.741655   0.574586  0.896552  0.700337  0.854264
# 4                  Knn  0.715530   0.550000  0.853448  0.668919  0.838320
# 0             Adaboost  0.740203   0.578171  0.844828  0.686515  0.836056
# 6  Logistic Regression  0.702467   0.539359  0.797414  0.643478  0.802790
# 1        Decision Tree  0.625544   0.462644  0.693966  0.555172  0.642053
# 7          Naive Bayes  0.687954   0.550898  0.396552  0.461153  0.706543
#
#      PR_AUC     EF@1%     EF@5%    EF@10%    BEDROC       MCC
# 9  0.835714  2.969828  2.884975  2.797664  0.889415  0.617113
# 2  0.830205  2.969828  2.969828  2.969828  0.922801  0.523077
# 5  0.819629  2.969828  2.969828  2.883746  0.907913  0.569507
# 8  0.819343  2.969828  2.969828  2.926787  0.922321  0.492851
# 3  0.789492  2.969828  2.969828  2.797664  0.881557  0.529577
# 4  0.781645  2.121305  2.206158  2.238131  0.605650  0.472086
# 0  0.766190  2.969828  2.969828  2.840705  0.879001  0.502820
# 6  0.669632  2.969828  2.460714  2.367254  0.664904  0.426922
# 1  0.629626  1.697044  1.697044  1.549475  0.281950  0.269177
# 7  0.586213  2.121305  0.933374  1.162106  0.108748  0.256340
#
# Saved results to: pubchem_test/metrics_atompair.csv

# %%
import os
import glob
import joblib
import numpy as np
import pandas as pd

from rdkit import Chem
from rdkit.Chem import rdMolDescriptors

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, precision_recall_curve, auc,
    matthews_corrcoef
)

# ------------------------------------------------------------
# Paths
# ------------------------------------------------------------
PUBCHEM_FILE = "dataset/pubchem_clean.csv"
MODEL_DIR = "saved_models/chembl_ecfp4"
OUTPUT_FILE = "pubchem_test/metrics_ecfp4.csv"

# ------------------------------------------------------------
# Load dataset
# ------------------------------------------------------------
df = pd.read_csv(PUBCHEM_FILE)

smiles_col = "standard_smiles"
label_col = "class"

if smiles_col not in df.columns:
    raise ValueError(f"Column '{smiles_col}' not found in {PUBCHEM_FILE}")

if label_col not in df.columns:
    raise ValueError(
        f"Column '{label_col}' not found in {PUBCHEM_FILE}. "
        f"You need true labels to compute the evaluation table."
    )

# ------------------------------------------------------------
# Convert SMILES to molecules
# ------------------------------------------------------------
df["mol"] = df[smiles_col].apply(Chem.MolFromSmiles)
df = df[df["mol"].notnull()].copy().reset_index(drop=True)

print(f"Valid molecules: {len(df)}")

# ------------------------------------------------------------
# Generate the SAME fingerprint used during training
# ------------------------------------------------------------
from rdkit.Chem import AllChem
from rdkit import DataStructs

def mol_to_morgan_fp(mol):
    fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius=2, nBits=2048)
    
    # Convert RDKit ExplicitBitVect → NumPy array
    arr = np.zeros((1,), dtype=int)
    DataStructs.ConvertToNumpyArray(fp, arr)
    
    return arr

df['fp'] = df['mol'].apply(mol_to_morgan_fp)

X = np.array(df['fp'].tolist())
y = df['class'].astype(int)




# ------------------------------------------------------------
# Metrics functions
# ------------------------------------------------------------
def enrichment_factor(y_true, y_scores, top_percent=0.01):
    sorted_idx = np.argsort(y_scores)[::-1]
    y_true_sorted = np.array(y_true)[sorted_idx]

    n_total = len(y_true)
    n_actives = np.sum(y_true)

    top_n = int(np.ceil(top_percent * n_total))
    top_hits = y_true_sorted[:top_n]

    n_top_actives = np.sum(top_hits)

    if n_actives == 0 or top_n == 0:
        return 0.0

    ef = (n_top_actives / top_n) / (n_actives / n_total)
    return ef


def bedroc_score(y_true, y_scores, alpha=20.0):
    y_true = np.array(y_true)
    y_scores = np.array(y_scores)

    order = np.argsort(y_scores)[::-1]
    y_true = y_true[order]

    n = len(y_true)
    n_pos = np.sum(y_true)

    if n_pos == 0:
        return 0.0

    ranks = np.where(y_true == 1)[0] + 1   # 1-based ranks
    ri = ranks / n

    rie = np.sum(np.exp(-alpha * ri)) / n_pos

    rand = (1 - np.exp(-alpha)) / alpha
    max_rie = (1 - np.exp(-alpha * (n_pos / n))) / (alpha * (n_pos / n))

    if max_rie == rand:
        return 0.0

    bedroc = (rie - rand) / (max_rie - rand)
    return bedroc

# ------------------------------------------------------------
# Load all saved models
# ------------------------------------------------------------
model_files = sorted(glob.glob(os.path.join(MODEL_DIR, "*.joblib")))

if not model_files:
    raise FileNotFoundError(f"No saved model found in {MODEL_DIR}")

# nice model names from filenames
def clean_model_name(path):
    name = os.path.splitext(os.path.basename(path))[0]
    return name.replace("_", " ").title()

# ------------------------------------------------------------
# Evaluate all models on PubChem
# ------------------------------------------------------------
results = []

for model_path in model_files:
    model_name = clean_model_name(model_path)
    print(f"\nEvaluating {model_name} ...")

    model = joblib.load(model_path)

    y_pred = model.predict(X)

    if hasattr(model, "predict_proba"):
        y_prob = model.predict_proba(X)[:, 1]
    else:
        y_prob = None

    acc = accuracy_score(y, y_pred)
    prec = precision_score(y, y_pred, zero_division=0)
    rec = recall_score(y, y_pred, zero_division=0)
    f1 = f1_score(y, y_pred, zero_division=0)
    mcc = matthews_corrcoef(y, y_pred)

    if y_prob is not None:
        roc = roc_auc_score(y, y_prob)

        p, r, _ = precision_recall_curve(y, y_prob)
        pra = auc(r, p)

        ef1 = enrichment_factor(y, y_prob, top_percent=0.01)
        ef5 = enrichment_factor(y, y_prob, top_percent=0.05)
        ef10 = enrichment_factor(y, y_prob, top_percent=0.10)

        bedroc = bedroc_score(y, y_prob, alpha=20)
    else:
        roc = np.nan
        pra = np.nan
        ef1 = np.nan
        ef5 = np.nan
        ef10 = np.nan
        bedroc = np.nan

    results.append([
        model_name, acc, prec, rec, f1, roc, pra, ef1, ef5, ef10, bedroc, mcc
    ])

# ------------------------------------------------------------
# Results table
# ------------------------------------------------------------
columns = [
    "Model",
    "Accuracy",
    "Precision",
    "Recall",
    "F1",
    "ROC_AUC",
    "PR_AUC",
    "EF@1%",
    "EF@5%",
    "EF@10%",
    "BEDROC",
    "MCC"
]

results_df = pd.DataFrame(results, columns=columns)
results_df = results_df.sort_values("PR_AUC", ascending=False)

print("\n==================== PUBCHEM TEST RESULTS ====================")
print(results_df)

results_df.to_csv(OUTPUT_FILE, index=False)
print(f"\nSaved results to: {OUTPUT_FILE}")
# Out:
# Valid molecules: 689
#
# Evaluating Adaboost ...
#
# Evaluating Decision Tree ...
#
# Evaluating Extra Trees ...
#
# Evaluating Gradient Boosting ...
#
# Evaluating Knn ...
#
# Evaluating Lightgbm ...
#
# Evaluating Logistic Regression ...
#
# Evaluating Naive Bayes ...
#
# Evaluating Random Forest ...
#
# Evaluating Svm ...
#
# ==================== PUBCHEM TEST RESULTS ====================
#                  Model  Accuracy  Precision    Recall        F1   ROC_AUC  \
# 8        Random Forest  0.788099   0.637821  0.857759  0.731618  0.889822
# 9                  Svm  0.801161   0.663230  0.831897  0.738050  0.894571
# 2          Extra Trees  0.785196   0.634615  0.853448  0.727941  0.887205
# 5             Lightgbm  0.779390   0.632450  0.823276  0.715356  0.878914
# 3    Gradient Boosting  0.738752   0.573446  0.875000  0.692833  0.870907
# 4                  Knn  0.751814   0.592705  0.840517  0.695187  0.854627
# 6  Logistic Regression  0.730044   0.568452  0.823276  0.672535  0.849845
# 1        Decision Tree  0.640058   0.479487  0.806034  0.601286  0.680917
# 7          Naive Bayes  0.615385   0.460621  0.831897  0.592934  0.666118
# 0             Adaboost  0.724238   0.562500  0.814655  0.665493  0.782794
#
#      PR_AUC     EF@1%     EF@5%    EF@10%    BEDROC       MCC
# 8  0.856553  2.969828  2.969828  2.926787  0.939713  0.579609
# 9  0.851238  2.969828  2.969828  2.883746  0.926567  0.590771
# 2  0.843823  2.969828  2.884975  2.883746  0.915817  0.573440
# 5  0.830088  2.969828  2.969828  2.797664  0.912698  0.552791
# 3  0.811217  2.969828  2.969828  2.883746  0.902201  0.514924
# 4  0.807236  2.969828  2.800123  2.539418  0.817391  0.517820
# 6  0.804864  2.969828  2.969828  2.969828  0.925000  0.478395
# 1  0.675417  1.697044  0.933374  1.032984  0.044861  0.345019
# 7  0.670519  0.424261  1.018227  1.291229  0.012723  0.326600
# 0  0.669264  2.969828  2.291010  2.496377  0.674659  0.466106
#
# Saved results to: pubchem_test/metrics_ecfp4.csv

# %%
import os
import glob
import joblib
import numpy as np
import pandas as pd

from rdkit import Chem
from rdkit.Chem import rdMolDescriptors
from rdkit.Avalon.pyAvalonTools import GetAvalonFP

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, precision_recall_curve, auc,
    matthews_corrcoef
)

# ------------------------------------------------------------
# Paths
# ------------------------------------------------------------
PUBCHEM_FILE = "dataset/pubchem_clean.csv"
MODEL_DIR = "saved_models/chembl_avalon"
OUTPUT_FILE = "pubchem_test/metrics_avalon.csv"

# ------------------------------------------------------------
# Load dataset
# ------------------------------------------------------------
df = pd.read_csv(PUBCHEM_FILE)

smiles_col = "standard_smiles"
label_col = "class"

if smiles_col not in df.columns:
    raise ValueError(f"Column '{smiles_col}' not found in {PUBCHEM_FILE}")

if label_col not in df.columns:
    raise ValueError(
        f"Column '{label_col}' not found in {PUBCHEM_FILE}. "
        f"You need true labels to compute the evaluation table."
    )

# ------------------------------------------------------------
# Convert SMILES to molecules
# ------------------------------------------------------------
df["mol"] = df[smiles_col].apply(Chem.MolFromSmiles)
df = df[df["mol"].notnull()].copy().reset_index(drop=True)

print(f"Valid molecules: {len(df)}")

# ------------------------------------------------------------
# Generate the SAME fingerprint used during training
# ------------------------------------------------------------
def mol_to_avalon_fp(mol):
    return GetAvalonFP(mol, nBits=1024)

df['fp'] = df['mol'].apply(mol_to_avalon_fp)

X = np.array([np.array(fp) for fp in df['fp']])
y = df['class'].astype(int)




# ------------------------------------------------------------
# Metrics functions
# ------------------------------------------------------------
def enrichment_factor(y_true, y_scores, top_percent=0.01):
    sorted_idx = np.argsort(y_scores)[::-1]
    y_true_sorted = np.array(y_true)[sorted_idx]

    n_total = len(y_true)
    n_actives = np.sum(y_true)

    top_n = int(np.ceil(top_percent * n_total))
    top_hits = y_true_sorted[:top_n]

    n_top_actives = np.sum(top_hits)

    if n_actives == 0 or top_n == 0:
        return 0.0

    ef = (n_top_actives / top_n) / (n_actives / n_total)
    return ef


def bedroc_score(y_true, y_scores, alpha=20.0):
    y_true = np.array(y_true)
    y_scores = np.array(y_scores)

    order = np.argsort(y_scores)[::-1]
    y_true = y_true[order]

    n = len(y_true)
    n_pos = np.sum(y_true)

    if n_pos == 0:
        return 0.0

    ranks = np.where(y_true == 1)[0] + 1   # 1-based ranks
    ri = ranks / n

    rie = np.sum(np.exp(-alpha * ri)) / n_pos

    rand = (1 - np.exp(-alpha)) / alpha
    max_rie = (1 - np.exp(-alpha * (n_pos / n))) / (alpha * (n_pos / n))

    if max_rie == rand:
        return 0.0

    bedroc = (rie - rand) / (max_rie - rand)
    return bedroc

# ------------------------------------------------------------
# Load all saved models
# ------------------------------------------------------------
model_files = sorted(glob.glob(os.path.join(MODEL_DIR, "*.joblib")))

if not model_files:
    raise FileNotFoundError(f"No saved model found in {MODEL_DIR}")

# nice model names from filenames
def clean_model_name(path):
    name = os.path.splitext(os.path.basename(path))[0]
    return name.replace("_", " ").title()

# ------------------------------------------------------------
# Evaluate all models on PubChem
# ------------------------------------------------------------
results = []

for model_path in model_files:
    model_name = clean_model_name(model_path)
    print(f"\nEvaluating {model_name} ...")

    model = joblib.load(model_path)

    y_pred = model.predict(X)

    if hasattr(model, "predict_proba"):
        y_prob = model.predict_proba(X)[:, 1]
    else:
        y_prob = None

    acc = accuracy_score(y, y_pred)
    prec = precision_score(y, y_pred, zero_division=0)
    rec = recall_score(y, y_pred, zero_division=0)
    f1 = f1_score(y, y_pred, zero_division=0)
    mcc = matthews_corrcoef(y, y_pred)

    if y_prob is not None:
        roc = roc_auc_score(y, y_prob)

        p, r, _ = precision_recall_curve(y, y_prob)
        pra = auc(r, p)

        ef1 = enrichment_factor(y, y_prob, top_percent=0.01)
        ef5 = enrichment_factor(y, y_prob, top_percent=0.05)
        ef10 = enrichment_factor(y, y_prob, top_percent=0.10)

        bedroc = bedroc_score(y, y_prob, alpha=20)
    else:
        roc = np.nan
        pra = np.nan
        ef1 = np.nan
        ef5 = np.nan
        ef10 = np.nan
        bedroc = np.nan

    results.append([
        model_name, acc, prec, rec, f1, roc, pra, ef1, ef5, ef10, bedroc, mcc
    ])

# ------------------------------------------------------------
# Results table
# ------------------------------------------------------------
columns = [
    "Model",
    "Accuracy",
    "Precision",
    "Recall",
    "F1",
    "ROC_AUC",
    "PR_AUC",
    "EF@1%",
    "EF@5%",
    "EF@10%",
    "BEDROC",
    "MCC"
]

results_df = pd.DataFrame(results, columns=columns)
results_df = results_df.sort_values("PR_AUC", ascending=False)

print("\n==================== PUBCHEM TEST RESULTS ====================")
print(results_df)

results_df.to_csv(OUTPUT_FILE, index=False)
print(f"\nSaved results to: {OUTPUT_FILE}")
# Out:
# Valid molecules: 689
#
# Evaluating Adaboost ...
#
# Evaluating Decision Tree ...
#
# Evaluating Extra Trees ...
#
# Evaluating Gradient Boosting ...
#
# Evaluating Knn ...
#
# Evaluating Lightgbm ...
#
# Evaluating Logistic Regression ...
#
# Evaluating Naive Bayes ...
#
# Evaluating Random Forest ...
#
# Evaluating Svm ...
#
# ==================== PUBCHEM TEST RESULTS ====================
#                  Model  Accuracy  Precision    Recall        F1   ROC_AUC  \
# 8        Random Forest  0.695210   0.530055  0.836207  0.648829  0.864092
# 2          Extra Trees  0.702467   0.537190  0.840517  0.655462  0.861517
# 5             Lightgbm  0.744557   0.588608  0.801724  0.678832  0.852496
# 9                  Svm  0.757620   0.601881  0.827586  0.696915  0.862050
# 4                  Knn  0.664731   0.501272  0.849138  0.630400  0.833641
# 3    Gradient Boosting  0.673440   0.509138  0.840517  0.634146  0.814320
# 0             Adaboost  0.658926   0.496164  0.836207  0.622793  0.774070
# 1        Decision Tree  0.609579   0.453634  0.780172  0.573693  0.650985
# 7          Naive Bayes  0.645864   0.484694  0.818966  0.608974  0.710566
# 6  Logistic Regression  0.699565   0.535211  0.818966  0.647359  0.795556
#
#      PR_AUC     EF@1%     EF@5%    EF@10%    BEDROC       MCC
# 8  0.835820  2.969828  2.969828  2.926787  0.938269  0.435478
# 2  0.828276  2.969828  2.969828  2.797664  0.921936  0.447622
# 5  0.809666  2.969828  2.969828  2.754623  0.911689  0.490584
# 9  0.807727  2.969828  2.969828  2.840705  0.898862  0.520980
# 4  0.785909  1.697044  2.715271  2.539418  0.754692  0.401210
# 3  0.738439  2.969828  2.969828  2.754623  0.867055  0.408169
# 0  0.680057  2.969828  2.715271  2.582459  0.782293  0.386460
# 1  0.653619  1.272783  1.781897  1.678598  0.321179  0.290183
# 7  0.651928  2.545567  1.697044  1.764680  0.372328  0.359722
# 6  0.650822  2.121305  2.630419  2.152049  0.634594  0.433012
#
# Saved results to: pubchem_test/metrics_avalon.csv
