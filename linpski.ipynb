# %%
from rdkit import Chem
from rdkit.Chem import Descriptors

def lipinski(smiles):
    mol = Chem.MolFromSmiles(smiles)
    
    mw = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    hbd = Descriptors.NumHDonors(mol)
    hba = Descriptors.NumHAcceptors(mol)
    
    violations = sum([
        mw > 500,
        logp > 5,
        hbd > 5,
        hba > 10
    ])
    
    return {
        "MW": mw,
        "LogP": logp,
        "HBD": hbd,
        "HBA": hba,
        "Violations": violations
    }

# Example
smiles1 = "CCCOc1ccc(-c2ccc3oc(=O)ccc3c2)cc1"  # Aspirin
smiles2 = "CCCOc1ccc(-c2cncc(CN3CCCC3)c2)cc1"  # Aspirin
smiles3 = "CCCOc1ccc(-c2nc(C)nc3c2CCCC3)cc1"  # Aspirin
smiles4 = "CCCOc1ccc(-c2ncccc2CN2CCCC2)cc1"  # Aspirin
print(lipinski(smiles1))
print(lipinski(smiles2))
print(lipinski(smiles3))
print(lipinski(smiles4))
# Out:
# {'MW': 280.323, 'LogP': 4.248800000000003, 'HBD': 0, 'HBA': 3, 'Violations': 0}
# {'MW': 296.41399999999993, 'LogP': 4.133200000000003, 'HBD': 0, 'HBA': 3, 'Violations': 0}
# {'MW': 282.38699999999994, 'LogP': 4.119620000000003, 'HBD': 0, 'HBA': 3, 'Violations': 0}
# {'MW': 296.414, 'LogP': 4.133200000000003, 'HBD': 0, 'HBA': 3, 'Violations': 0}

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors

def lipinski(smiles, name="Compound"):
    mol = Chem.MolFromSmiles(smiles)
    
    if mol is None:
        return {"Name": name, "Error": "Invalid SMILES"}
    
    mw = round(Descriptors.MolWt(mol), 2)
    logp = round(Descriptors.MolLogP(mol), 2)
    hbd = Descriptors.NumHDonors(mol)
    hba = Descriptors.NumHAcceptors(mol)
    
    violations = sum([
        mw > 500,
        logp > 5,
        hbd > 5,
        hba > 10
    ])
    
    return {
        "Name": name,
        "MW": mw,
        "LogP": logp,
        "HBD": hbd,
        "HBA": hba,
        "Violations": violations
    }


# Your compounds
smiles_list = [
    ("C1", "CCCOc1ccc(-c2ccc3oc(=O)ccc3c2)cc1"),
    ("C2", "CCCOc1ccc(-c2cncc(CN3CCCC3)c2)cc1"),
    ("C3", "CCCOc1ccc(-c2nc(C)nc3c2CCCC3)cc1"),
    ("C4", "CCCOc1ccc(-c2ncccc2CN2CCCC2)cc1")
]

results = [lipinski(s, name) for name, s in smiles_list]

for r in results:
    print(r)
# Out:
# {'Name': 'C1', 'MW': 280.32, 'LogP': 4.25, 'HBD': 0, 'HBA': 3, 'Violations': 0}
# {'Name': 'C2', 'MW': 296.41, 'LogP': 4.13, 'HBD': 0, 'HBA': 3, 'Violations': 0}
# {'Name': 'C3', 'MW': 282.39, 'LogP': 4.12, 'HBD': 0, 'HBA': 3, 'Violations': 0}
# {'Name': 'C4', 'MW': 296.41, 'LogP': 4.13, 'HBD': 0, 'HBA': 3, 'Violations': 0}
